# %% [markdown]
# <a href="https://colab.research.google.com/github/Mreeb/YOLO-V8-CLASSIFICATION-ON_Dermnet/blob/master/Classification_Orignal_Dermnet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Connect Runtime To a GPU

# %%
# !nvidia-smi
# Out:
# Fri Dec 15 21:09:00 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   55C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# # Installing Libraies

# %%
# !pip install --upgrade numpy
# !pip install ultralytics==8.0.58 roboflow numpy==1.24.2
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.23.5)
# Collecting numpy
#   Downloading numpy-1.26.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 32.6 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.5
#     Uninstalling numpy-1.23.5:
#       Successfully uninstalled numpy-1.23.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# Successfully installed numpy-1.26.2
# Collecting ultralytics==8.0.58
#   Downloading ultralytics-8.0.58-py3-none-any.whl (486 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.8/486.8 kB 8.0 MB/s eta 0:00:00
# Collecting roboflow
#   Downloading roboflow-1.1.12-py3-none-any.whl (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.5/68.5 kB 6.2 MB/s eta 0:00:00
# Collecting numpy==1.24.2
#   Downloading numpy-1.24.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 61.8 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.0.58) (3.7.1)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.0.58) (4.8.0.76)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.0.58) (9.4.0)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.0.58) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.0.58) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.0.58) (1.11.4)
# Requirement already satisfied: torch>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.0.58) (2.1.0+cu121)
# Requirement already satisfied: torchvision>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.0.58) (0.16.0+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.0.58) (4.66.1)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.0.58) (1.5.3)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.0.58) (0.12.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.0.58) (5.9.5)
# Collecting thop>=0.1.1 (from ultralytics==8.0.58)
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Collecting sentry-sdk (from ultralytics==8.0.58)
#   Downloading sentry_sdk-1.39.1-py2.py3-none-any.whl (254 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.1/254.1 kB 32.6 MB/s eta 0:00:00
# Collecting certifi==2023.7.22 (from roboflow)
#   Downloading certifi-2023.7.22-py3-none-any.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 21.6 MB/s eta 0:00:00
# Collecting chardet==4.0.0 (from roboflow)
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 25.2 MB/s eta 0:00:00
# Collecting cycler==0.10.0 (from roboflow)
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting idna==2.10 (from roboflow)
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 5.1 MB/s eta 0:00:00
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.4.5)
# Collecting opencv-python-headless==4.8.0.74 (from roboflow)
#   Downloading opencv_python_headless-4.8.0.74-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 10.2 MB/s eta 0:00:00
# Collecting pyparsing==2.4.7 (from roboflow)
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 9.1 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.8.2)
# Collecting python-dotenv (from roboflow)
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.16.0)
# Collecting supervision (from roboflow)
#   Downloading supervision-0.17.1-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.5/77.5 kB 11.0 MB/s eta 0:00:00
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.0.7)
# Collecting requests-toolbelt (from roboflow)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.6 MB/s eta 0:00:00
# Collecting python-magic (from roboflow)
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->ultralytics==8.0.58) (1.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->ultralytics==8.0.58) (4.46.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->ultralytics==8.0.58) (23.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics==8.0.58) (2023.3.post1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics==8.0.58) (3.3.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->ultralytics==8.0.58) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->ultralytics==8.0.58) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->ultralytics==8.0.58) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->ultralytics==8.0.58) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->ultralytics==8.0.58) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->ultralytics==8.0.58) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->ultralytics==8.0.58) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.7.0->ultralytics==8.0.58) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.7.0->ultralytics==8.0.58) (1.3.0)
# Installing collected packages: python-magic, python-dotenv, pyparsing, numpy, idna, cycler, chardet, certifi, sentry-sdk, opencv-python-headless, thop, requests-toolbelt, supervision, ultralytics, roboflow
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.2
#     Uninstalling numpy-1.26.2:
#       Successfully uninstalled numpy-1.26.2
#   Attempting uninstall: idna
#     Found existing installation: idna 3.6
#     Uninstalling idna-3.6:
#       Successfully uninstalled idna-3.6
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.12.1
#     Uninstalling cycler-0.12.1:
#       Successfully uninstalled cycler-0.12.1
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
#     Uninstalling chardet-5.2.0:
#       Successfully uninstalled chardet-5.2.0
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2023.11.17
#     Uninstalling certifi-2023.11.17:
#       Successfully uninstalled certifi-2023.11.17
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.8.1.78
#     Uninstalling opencv-python-headless-4.8.1.78:
#       Successfully uninstalled opencv-python-headless-4.8.1.78
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# Successfully installed certifi-2023.7.22 chardet-4.0.0 cycler-0.10.0 idna-2.10 numpy-1.24.2 opencv-python-headless-4.8.0.74 pyparsing-2.4.7 python-dotenv-1.0.0 python-magic-0.4.27 requests-toolbelt-1.0.0 roboflow-1.1.12 sentry-sdk-1.39.1 supervision-0.17.1 thop-0.1.1.post2209072238 ultralytics-8.0.58

# %% [markdown]
# # Mounting Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from ultralytics import YOLO

model_path = 'yolov8x-cls.pt'  # @param {type:"string"}
data_path = '/content/drive/MyDrive/Dermnet'  # @param {type:"string"}

epochs = 100  # @param {type:"integer"}
img_size = 224  # @param {type:"integer"}
amp = False # @param {type:"boolean"}
cache = True # @param {type:"boolean"}

patience = 20 # @param {type:"integer"}

# Create YOLO model and train
model = YOLO(model_path)
model.train(data=data_path, epochs=epochs, imgsz=img_size, amp = amp, cache = cache, patience=patience)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8x-cls.pt to yolov8x-cls.pt...
# 100%|██████████| 110M/110M [00:00<00:00, 235MB/s]
# New https://pypi.org/project/ultralytics/8.0.227 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.58 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# yolo/engine/trainer: task=classify, mode=train, model=yolov8x-cls.pt, data=/content/drive/MyDrive/Dermnet, epochs=100, patience=20, batch=16, imgsz=224, save=True, save_period=-1, cache=True, device=None, workers=8, project=None, name=None, exist_ok=False, pretrained=False, optimizer=SGD, verbose=True, seed=0, deterministic=True, single_cls=False, image_weights=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, hide_labels=False, hide_conf=False, vid_stride=1, line_thickness=3, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, fl_gamma=0.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, v5loader=False, tracker=botsort.yaml, save_dir=runs/classify/train
# Overriding model.yaml nc=1000 with nc=11
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      2320  ultralytics.nn.modules.Conv                  [3, 80, 3, 2]
#   1                  -1  1    115520  ultralytics.nn.modules.Conv                  [80, 160, 3, 2]
#   2                  -1  3    436800  ultralytics.nn.modules.C2f                   [160, 160, 3, True]
#   3                  -1  1    461440  ultralytics.nn.modules.Conv                  [160, 320, 3, 2]
#   4                  -1  6   3281920  ultralytics.nn.modules.C2f                   [320, 320, 6, True]
#   5                  -1  1   1844480  ultralytics.nn.modules.Conv                  [320, 640, 3, 2]
#   6                  -1  6  13117440  ultralytics.nn.modules.C2f                   [640, 640, 6, True]
#   7                  -1  1   7375360  ultralytics.nn.modules.Conv                  [640, 1280, 3, 2]
#   8                  -1  3  27865600  ultralytics.nn.modules.C2f                   [1280, 1280, 3, True]
#   9                  -1  1   1655051  ultralytics.nn.modules.Classify              [1280, 11]
# YOLOv8x-cls summary: 183 layers, 56155931 parameters, 56155931 gradients, 154.3 GFLOPs
# Transferred 300/302 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/classify/train', view at http://localhost:6006/
# optimizer: SGD(lr=0.01) with parameter groups 50 weight(decay=0.0), 51 weight(decay=0.0005), 51 bias
# albumentations: module 'numpy' has no attribute '_no_nep50_warning'
# Image sizes 224 train, 224 val
# Using 2 dataloader workers
# Logging results to runs/classify/train
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#       1/100      3.24G     0.5882          6        224: 100%|██████████| 347/347 [22:38<00:00,  3.91s/it]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [04:38<00:00, 11.60s/it]
#                    all       0.21      0.594
#
#       Epoch    GPU_mem       loss  Instances       Size
#       2/100      3.25G     0.5748          6        224: 100%|██████████| 347/347 [01:36<00:00,  3.58it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:08<00:00,  2.69it/s]
#                    all      0.225      0.626
#
#       Epoch    GPU_mem       loss  Instances       Size
#       3/100      3.25G     0.5681          6        224: 100%|██████████| 347/347 [01:35<00:00,  3.62it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:09<00:00,  2.62it/s]
#                    all      0.253       0.65
#
#       Epoch    GPU_mem       loss  Instances       Size
#       4/100      3.25G     0.5591          6        224: 100%|██████████| 347/347 [01:35<00:00,  3.63it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:09<00:00,  2.48it/s]
#                    all      0.273      0.685
#
#       Epoch    GPU_mem       loss  Instances       Size
#       5/100      3.25G     0.5502          6        224: 100%|██████████| 347/347 [01:35<00:00,  3.64it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:10<00:00,  2.26it/s]
#                    all       0.26      0.706
#
#       Epoch    GPU_mem       loss  Instances       Size
#       6/100      3.25G     0.5401          6        224: 100%|██████████| 347/347 [01:35<00:00,  3.64it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:11<00:00,  2.17it/s]
#                    all       0.29      0.703
#
#       Epoch    GPU_mem       loss  Instances       Size
#       7/100      3.25G     0.5276          6        224: 100%|██████████| 347/347 [01:35<00:00,  3.63it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:12<00:00,  1.89it/s]
#                    all      0.322      0.735
#
#       Epoch    GPU_mem       loss  Instances       Size
#       8/100      3.25G     0.5173          6        224: 100%|██████████| 347/347 [01:35<00:00,  3.63it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:11<00:00,  2.14it/s]
#                    all      0.296      0.725
#
#       Epoch    GPU_mem       loss  Instances       Size
#       9/100      3.25G      0.504          6        224: 100%|██████████| 347/347 [01:35<00:00,  3.63it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:09<00:00,  2.41it/s]
#                    all      0.283      0.713
#
#       Epoch    GPU_mem       loss  Instances       Size
#      10/100      3.25G     0.4917          6        224: 100%|██████████| 347/347 [01:35<00:00,  3.64it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:08<00:00,  2.68it/s]
#                    all      0.285      0.748
#
#       Epoch    GPU_mem       loss  Instances       Size
#      11/100      3.25G      0.479          6        224: 100%|██████████| 347/347 [01:35<00:00,  3.62it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:10<00:00,  2.35it/s]
#                    all      0.351      0.762
#
#       Epoch    GPU_mem       loss  Instances       Size
#      12/100      3.25G     0.4614          6        224: 100%|██████████| 347/347 [01:35<00:00,  3.64it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:09<00:00,  2.54it/s]
#                    all      0.382      0.776
#
#       Epoch    GPU_mem       loss  Instances       Size
#      13/100      3.25G     0.4396          6        224: 100%|██████████| 347/347 [01:35<00:00,  3.64it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:09<00:00,  2.59it/s]
#                    all      0.384      0.781
#
#       Epoch    GPU_mem       loss  Instances       Size
#      14/100      3.25G     0.4151          6        224: 100%|██████████| 347/347 [01:36<00:00,  3.61it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:09<00:00,  2.48it/s]
#                    all      0.396      0.794
#
#       Epoch    GPU_mem       loss  Instances       Size
#      15/100      3.25G     0.3801          6        224: 100%|██████████| 347/347 [01:35<00:00,  3.63it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:09<00:00,  2.54it/s]
#                    all      0.401      0.804
#
#       Epoch    GPU_mem       loss  Instances       Size
#      16/100      3.25G     0.3366          6        224: 100%|██████████| 347/347 [01:35<00:00,  3.63it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:11<00:00,  2.08it/s]
#                    all      0.412      0.799
#
#       Epoch    GPU_mem       loss  Instances       Size
#      17/100      3.25G     0.2958          6        224: 100%|██████████| 347/347 [01:35<00:00,  3.62it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:08<00:00,  2.70it/s]
#                    all       0.42      0.784
#
#       Epoch    GPU_mem       loss  Instances       Size
#      18/100      3.25G     0.2444          6        224: 100%|██████████| 347/347 [01:35<00:00,  3.64it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:10<00:00,  2.29it/s]
#                    all      0.454      0.802
#
#       Epoch    GPU_mem       loss  Instances       Size
#      19/100      3.25G     0.2014          6        224: 100%|██████████| 347/347 [01:35<00:00,  3.64it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:11<00:00,  2.16it/s]
#                    all      0.426      0.789
#
#       Epoch    GPU_mem       loss  Instances       Size
#      20/100      3.25G     0.1567          6        224: 100%|██████████| 347/347 [01:35<00:00,  3.64it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:10<00:00,  2.28it/s]
#                    all      0.448      0.782
#
#       Epoch    GPU_mem       loss  Instances       Size
#      21/100      3.25G     0.1232          6        224: 100%|██████████| 347/347 [01:35<00:00,  3.63it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:11<00:00,  2.14it/s]
#                    all      0.447      0.806
#
#       Epoch    GPU_mem       loss  Instances       Size
#      22/100      3.25G    0.09153          6        224: 100%|██████████| 347/347 [01:35<00:00,  3.64it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:11<00:00,  2.14it/s]
#                    all      0.462       0.79
#
#       Epoch    GPU_mem       loss  Instances       Size
#      23/100      3.25G    0.07014          6        224: 100%|██████████| 347/347 [01:35<00:00,  3.63it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:11<00:00,  2.14it/s]
#                    all      0.462      0.803
#
#       Epoch    GPU_mem       loss  Instances       Size
#      24/100      3.25G    0.05917          6        224: 100%|██████████| 347/347 [01:35<00:00,  3.63it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:09<00:00,  2.43it/s]
#                    all      0.468      0.792
#
#       Epoch    GPU_mem       loss  Instances       Size
#      25/100      3.25G    0.04217          6        224: 100%|██████████| 347/347 [01:35<00:00,  3.63it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:11<00:00,  2.17it/s]
#                    all      0.449      0.794
#
#       Epoch    GPU_mem       loss  Instances       Size
#      26/100      3.25G    0.03461          6        224: 100%|██████████| 347/347 [01:35<00:00,  3.63it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:10<00:00,  2.25it/s]
#                    all      0.466       0.81
#
#       Epoch    GPU_mem       loss  Instances       Size
#      27/100      3.25G    0.02777          6        224: 100%|██████████| 347/347 [01:35<00:00,  3.62it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:10<00:00,  2.19it/s]
#                    all      0.472        0.8
#
#       Epoch    GPU_mem       loss  Instances       Size
#      28/100      3.25G    0.02245          6        224: 100%|██████████| 347/347 [01:35<00:00,  3.64it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:11<00:00,  2.11it/s]
#                    all      0.451      0.786
#
#       Epoch    GPU_mem       loss  Instances       Size
#      29/100      3.25G    0.01818          6        224: 100%|██████████| 347/347 [01:35<00:00,  3.64it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:09<00:00,  2.57it/s]
#                    all      0.457      0.796
#
#       Epoch    GPU_mem       loss  Instances       Size
#      30/100      3.25G    0.01478          6        224: 100%|██████████| 347/347 [01:35<00:00,  3.62it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:08<00:00,  2.78it/s]
#                    all      0.463      0.794
#
#       Epoch    GPU_mem       loss  Instances       Size
#      31/100      3.25G    0.01168          6        224: 100%|██████████| 347/347 [01:35<00:00,  3.64it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:10<00:00,  2.19it/s]
#                    all      0.471      0.801
#
#       Epoch    GPU_mem       loss  Instances       Size
#      32/100      3.25G   0.007672          6        224: 100%|██████████| 347/347 [01:35<00:00,  3.63it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:10<00:00,  2.23it/s]
#                    all      0.461      0.792
#
#       Epoch    GPU_mem       loss  Instances       Size
#      33/100      3.25G   0.006264          6        224: 100%|██████████| 347/347 [01:35<00:00,  3.63it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:10<00:00,  2.31it/s]
#                    all       0.48      0.807
#
#       Epoch    GPU_mem       loss  Instances       Size
#      34/100      3.25G   0.005793          6        224: 100%|██████████| 347/347 [01:35<00:00,  3.62it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:11<00:00,  2.17it/s]
#                    all      0.482        0.8
#
#       Epoch    GPU_mem       loss  Instances       Size
#      35/100      3.25G   0.004845          6        224: 100%|██████████| 347/347 [01:35<00:00,  3.63it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:11<00:00,  2.14it/s]
#                    all      0.476        0.8
#
#       Epoch    GPU_mem       loss  Instances       Size
#      36/100      3.25G   0.003979          6        224: 100%|██████████| 347/347 [01:35<00:00,  3.64it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:10<00:00,  2.38it/s]
#                    all      0.478      0.797
#
#       Epoch    GPU_mem       loss  Instances       Size
#      37/100      3.25G   0.003837          6        224: 100%|██████████| 347/347 [01:35<00:00,  3.63it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:10<00:00,  2.39it/s]
#                    all      0.479      0.796
#
#       Epoch    GPU_mem       loss  Instances       Size
#      38/100      3.25G    0.00362          6        224: 100%|██████████| 347/347 [01:35<00:00,  3.63it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:11<00:00,  2.09it/s]
#                    all       0.48        0.8
#
#       Epoch    GPU_mem       loss  Instances       Size
#      39/100      3.25G   0.003287          6        224: 100%|██████████| 347/347 [01:35<00:00,  3.63it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:11<00:00,  2.12it/s]
#                    all      0.477      0.801
#
#       Epoch    GPU_mem       loss  Instances       Size
#      40/100      3.25G   0.003199          6        224: 100%|██████████| 347/347 [01:35<00:00,  3.62it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:08<00:00,  2.68it/s]
#                    all      0.477      0.805
#
#       Epoch    GPU_mem       loss  Instances       Size
#      41/100      3.25G   0.003399          6        224: 100%|██████████| 347/347 [01:35<00:00,  3.63it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:11<00:00,  2.18it/s]
#                    all      0.479      0.803
#
#       Epoch    GPU_mem       loss  Instances       Size
#      42/100      3.25G   0.002999          6        224: 100%|██████████| 347/347 [01:35<00:00,  3.63it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:11<00:00,  2.13it/s]
#                    all      0.474      0.802
#
#       Epoch    GPU_mem       loss  Instances       Size
#      43/100      3.25G   0.002965          6        224: 100%|██████████| 347/347 [01:35<00:00,  3.63it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:10<00:00,  2.29it/s]
#                    all       0.47      0.806
#
#       Epoch    GPU_mem       loss  Instances       Size
#      44/100      3.25G   0.003055          6        224: 100%|██████████| 347/347 [01:35<00:00,  3.64it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:09<00:00,  2.61it/s]
#                    all      0.471      0.796
#
#       Epoch    GPU_mem       loss  Instances       Size
#      45/100      3.25G   0.002723          6        224: 100%|██████████| 347/347 [01:35<00:00,  3.64it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:09<00:00,  2.57it/s]
#                    all       0.47      0.798
#
#       Epoch    GPU_mem       loss  Instances       Size
#      46/100      3.25G   0.002828          6        224: 100%|██████████| 347/347 [01:35<00:00,  3.64it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:10<00:00,  2.21it/s]
#                    all      0.477      0.798
# Stopping training early as no improvement observed in last 20 epochs. Best results observed at epoch 26, best model saved as best.pt.
# To update EarlyStopping(patience=20) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 46 epochs completed in 1.832 hours.
# Optimizer stripped from runs/classify/train/weights/last.pt, 112.5MB
# Optimizer stripped from runs/classify/train/weights/best.pt, 112.5MB
# Results saved to runs/classify/train
