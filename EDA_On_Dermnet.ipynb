# %% [markdown]
# <a href="https://colab.research.google.com/github/Mreeb/YOLO-V8-CLASSIFICATION-ON_Dermnet/blob/master/EDA_On_Dermnet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import matplotlib.pyplot as plt
import os

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = "/content/drive/MyDrive/Dermnet/train"

directories = [d for d in os.listdir(path) if os.path.isdir(os.path.join(path, d)) and d.lower() != '.ipynb_checkpoints']

num_directories = len(directories)

print(f'Total number of directories: {num_directories}')
print('List of directories:')
print(directories)
# Out:
# Total number of directories: 23
# List of directories:
# ['Eczema Photos', 'Actinic Keratosis Basal Cell Carcinoma and other Malignant Lesions', 'Atopic Dermatitis Photos', 'Systemic Disease', 'Vascular Tumors', 'Seborrheic Keratoses and other Benign Tumors', 'Warts Molluscum and other Viral Infections', 'Poison Ivy Photos and other Contact Dermatitis', 'Hair Loss Photos Alopecia and other Hair Diseases', 'Tinea Ringworm Candidiasis and other Fungal Infections', 'Lupus and other Connective Tissue diseases', 'Psoriasis pictures Lichen Planus and related diseases', 'Urticaria Hives', 'Light Diseases and Disorders of Pigmentation', 'Bullous Disease Photos', 'Vasculitis Photos', 'Nail Fungus and other Nail Disease', 'Acne and Rosacea Photos', 'Scabies Lyme Disease and other Infestations and Bites', 'Cellulitis Impetigo and other Bacterial Infections', 'Exanthems and Drug Eruptions', 'Herpes HPV and other STDs Photos', 'Melanoma Skin Cancer Nevi and Moles']

# %%
for directory in directories:
    directory_path = os.path.join(path, directory)
    num_images = len([f for f in os.listdir(directory_path) if f.lower().endswith(('.png', '.jpg', '.jpeg'))])
    print(f'Directory: {directory}, Number of Images: {num_images}')
# Out:
# Directory: Eczema Photos, Number of Images: 1235
# Directory: Actinic Keratosis Basal Cell Carcinoma and other Malignant Lesions, Number of Images: 1149
# Directory: Atopic Dermatitis Photos, Number of Images: 489
# Directory: Systemic Disease, Number of Images: 606
# Directory: Vascular Tumors, Number of Images: 482
# Directory: Seborrheic Keratoses and other Benign Tumors, Number of Images: 1371
# Directory: Warts Molluscum and other Viral Infections, Number of Images: 1086
# Directory: Poison Ivy Photos and other Contact Dermatitis, Number of Images: 260
# Directory: Hair Loss Photos Alopecia and other Hair Diseases, Number of Images: 239
# Directory: Tinea Ringworm Candidiasis and other Fungal Infections, Number of Images: 1300
# Directory: Lupus and other Connective Tissue diseases, Number of Images: 420
# Directory: Psoriasis pictures Lichen Planus and related diseases, Number of Images: 1405
# Directory: Urticaria Hives, Number of Images: 212
# Directory: Light Diseases and Disorders of Pigmentation, Number of Images: 568
# Directory: Bullous Disease Photos, Number of Images: 449
# Directory: Vasculitis Photos, Number of Images: 416
# Directory: Nail Fungus and other Nail Disease, Number of Images: 1040
# Directory: Acne and Rosacea Photos, Number of Images: 840
# Directory: Scabies Lyme Disease and other Infestations and Bites, Number of Images: 431
# Directory: Cellulitis Impetigo and other Bacterial Infections, Number of Images: 288
# Directory: Exanthems and Drug Eruptions, Number of Images: 404
# Directory: Herpes HPV and other STDs Photos, Number of Images: 405
# Directory: Melanoma Skin Cancer Nevi and Moles, Number of Images: 463

# %%
directory_names = []
image_counts = []

for i, directory in enumerate(directories):
    directory_path = os.path.join(path, directory)
    num_images = len([f for f in os.listdir(directory_path) if f.lower().endswith(('.png', '.jpg', '.jpeg'))])

    directory_names.append(str(i+1))
    image_counts.append(num_images)

plt.figure(figsize=(10, 6))
plt.bar(directory_names, image_counts, color='skyblue')
plt.xlabel('Directory')
plt.ylabel('Number of Images')
plt.title('Number of Images in Each Directory')
plt.xticks(rotation=0, ha='right')
plt.tight_layout()
plt.show()
